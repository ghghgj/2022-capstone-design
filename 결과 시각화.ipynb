# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# ### 스킵

# %%
val=pd.read_csv('/content/drive/Shareddrives/캡스톤디자인/시각화/val.csv')
val_pred=pd.read_csv('/content/drive/Shareddrives/캡스톤디자인/시각화/val_pred.csv')
test=pd.read_csv('/content/drive/Shareddrives/캡스톤디자인/시각화/test_set.csv')
test_pred=pd.read_csv('/content/drive/Shareddrives/캡스톤디자인/시각화/pred_test.csv')

# %%
val=pd.concat([val,val_pred])

# %%
test
# Out:
#       Unnamed: 0  RUL_PERCENTAGE  sum_cumulative  \
# 0              0        0.006006       -1.602940
# 1              1        0.009009       -1.593733
# 2              2        0.012012       -1.584354
# 3              3        0.015015       -1.575354
# 4              4        0.018018       -1.565657
# ...          ...             ...             ...
# 1856        1856        0.988571        1.796467
# 1857        1857        0.991429        1.808693
# 1858        1858        0.994286        1.820966
# 1859        1859        0.997143        1.833334
# 1860        1860        1.000000        1.845640
#
#       reconstruction_error_ewm_1_stand
# 0                            -1.197737
# 1                            -0.893831
# 2                             0.141438
# 3                            -0.290994
# 4                            -0.432107
# ...                                ...
# 1856                          0.850155
# 1857                          1.002040
# ...

# %%
test_pred['RUL_PERCENTAGE'] = test['RUL_PERCENTAGE']

# %%
test_pred
# Out:
#       Unnamed: 0  sum_cumulative  reconstruction_error_ewm_1_stand     Label  \
# 0              0       -1.602940                         -1.197737  0.027383
# 1              1       -1.593733                         -0.893831  0.027286
# 2              2       -1.584354                          0.141438  0.133038
# 3              3       -1.575354                         -0.290994  0.072372
# 4              4       -1.565657                         -0.432107  0.033960
# ...          ...             ...                               ...       ...
# 1856        1856        1.796467                          0.850155  0.873152
# 1857        1857        1.808693                          1.002040  0.874932
# 1858        1858        1.820966                          1.053410  0.879026
# 1859        1859        1.833334                          1.296569  0.882413
# 1860        1860        1.845640                          1.300485  0.883278
#
#       RUL_PERCENTAGE
# 0           0.006006
# ...

# %%
index = "/content/drive/Shareddrives/캡스톤디자인/동서기공 RUL data/testset_final_1212.csv"

# %%
index_df = pd.read_csv(index)
index_df
# Out:
#       Unnamed: 0  index
# 0              0   4936
# 1              1   4937
# 2              2   4938
# 3              3   4939
# 4              4   4940
# ...          ...    ...
# 1862        1862  30340
# 1863        1863  30341
# 1864        1864  30342
# 1865        1865  30343
# 1866        1866  30344
#
# [1867 rows x 2 columns]

# %%
merge= pd.merge(test_pred,index_df, how='inner',on='Unnamed: 0')
merge
# Out:
#       Unnamed: 0  sum_cumulative  reconstruction_error_ewm_1_stand     Label  \
# 0              0       -1.602940                         -1.197737  0.027383
# 1              1       -1.593733                         -0.893831  0.027286
# 2              2       -1.584354                          0.141438  0.133038
# 3              3       -1.575354                         -0.290994  0.072372
# 4              4       -1.565657                         -0.432107  0.033960
# ...          ...             ...                               ...       ...
# 1856        1856        1.796467                          0.850155  0.873152
# 1857        1857        1.808693                          1.002040  0.874932
# 1858        1858        1.820966                          1.053410  0.879026
# 1859        1859        1.833334                          1.296569  0.882413
# 1860        1860        1.845640                          1.300485  0.883278
#
#       RUL_PERCENTAGE  index
# ...

# %%
all= pd.read_json('/content/drive/Shareddrives/캡스톤디자인/동서기공 RUL data/data_1212.json')

# %%
info = all[['index','completion']]

# %%
info
# Out:
#        index  completion
# 0       4593           1
# 1       4594           1
# 2       4595           1
# 3       4596           1
# 4       4597           1
# ...      ...         ...
# 28117  37249          96
# 28118  37250          96
# 28119  37251          96
# 28120  37252          96
# 28121  37253          96
#
# [28122 rows x 2 columns]

# %%
test_merge= pd.merge(merge,info, how='inner', on='index')

# %%
test_merge
# Out:
#       Unnamed: 0  sum_cumulative  reconstruction_error_ewm_1_stand     Label  \
# 0              0       -1.602940                         -1.197737  0.027383
# 1              1       -1.593733                         -0.893831  0.027286
# 2              2       -1.584354                          0.141438  0.133038
# 3              3       -1.575354                         -0.290994  0.072372
# 4              4       -1.565657                         -0.432107  0.033960
# ...          ...             ...                               ...       ...
# 1856        1856        1.796467                          0.850155  0.873152
# 1857        1857        1.808693                          1.002040  0.874932
# 1858        1858        1.820966                          1.053410  0.879026
# 1859        1859        1.833334                          1.296569  0.882413
# 1860        1860        1.845640                          1.300485  0.883278
#
#       RUL_PERCENTAGE  index  completion
# ...

# %% [markdown]
# ### 여기서부터

# %%
c = pd.read_csv('/content/drive/Shareddrives/캡스톤디자인/동서기공 RUL data/plot_table.csv')

# %%
c
# Out:
#       Unnamed: 0  Unnamed: 0.1  sum_cumulative  \
# 0              0             0       -1.602940
# 1              1             1       -1.593733
# 2              2             2       -1.584354
# 3              3             3       -1.575354
# 4              4             4       -1.565657
# ...          ...           ...             ...
# 1856        1856          1856        1.796467
# 1857        1857          1857        1.808693
# 1858        1858          1858        1.820966
# 1859        1859          1859        1.833334
# 1860        1860          1860        1.845640
#
#       reconstruction_error_ewm_1_stand     Label  RUL_PERCENTAGE  index  \
# 0                            -1.197737  0.027383        0.006006   4936
# 1                            -0.893831  0.027286        0.009009   4937
# 2                             0.141438  0.133038        0.012012   4938
# 3                            -0.290994  0.072372        0.015015   4939
# ...

# %%
c['completion'].unique()
# Out:
# array([ 2, 23, 36, 42, 54, 71])

# %%
c['RUL'] = 1-c['RUL_PERCENTAGE']
c['predict'] = 1- c['Label']

# %%
plt.plot(c['RUL'])

# %%
plt.plot(c['predict'])

# %%
c['Label']=c['predict']
c['RUL_PERCENTAGE'] = c['RUL']

# %%
c1= c[c['completion']==2]
c2= c[c['completion']==23]
c3= c[c['completion']==36]
c4= c[c['completion']==42]
c5= c[c['completion']==54]
c6= c[c['completion']==71]

# %%
len(c4)
# Out:
# 162

# %%
c1.reset_index(inplace=True)
c2.reset_index(inplace=True)
c3.reset_index(inplace=True)
c4.reset_index(inplace=True)
c5.reset_index(inplace=True)
c6.reset_index(inplace=True)

# %%
import numpy as np

# %%
plt.plot(c['RUL_PERCENTAGE'])

# %%
plt.plot(c['Label'])

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
ax1.plot(np.arange(len(c1)), c1['Label'], 'b-', label="blue")
plt.ylim(0,1)
ax2.plot(np.arange(len(c1)), c1['RUL_PERCENTAGE'], 'g-', label="blue")
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='b')
ax2.set_ylabel('RUL', color='g')
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.ylim(0,1)
ax1.plot(np.arange(len(c2)), c2['Label'], 'r-')
ax2.plot(np.arange(len(c2)), c2['RUL_PERCENTAGE'], 'g-', label="blue")
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax2.set_ylabel('RUL', color='g')
plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c3)), c3['Label'], 'b-', label="green")
ax2.plot(np.arange(len(c3)), c3['RUL_PERCENTAGE'], 'g-', label="blue")
plt.ylim(0,1)
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='b')
ax2.set_ylabel('RUL', color='g')
plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c4)), c4['Label'], 'r-', label="green")
plt.ylim(0,1)
ax2.plot(np.arange(len(c4)), c4['RUL_PERCENTAGE'], 'g-', label="blue")
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')
plt.ylim(0,1)

plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c5)), c5['Label'], 'r-', label="green")
plt.ylim(0,1)
plt.plot(np.arange(len(c5)), c5['RUL_PERCENTAGE'], 'g-', label="blue")
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')
plt.xlim(0,350)

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c6)), c6['Label'], 'r-', label="green")
plt.ylim(0,1)
plt.plot(np.arange(len(c6)), c6['RUL_PERCENTAGE'], 'g-', label="blue")
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')
plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c4)), c4['Label'], 'r-', label="green")
plt.ylim(0,1)

plt.plot(np.arange(len(c1[:101])), c1['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c2[:101])), c2['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c3[:101])), c3['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c5[:101])), c5['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c6[:101])), c6['Label'][:101], 'b-', label="green")


ax2.plot(np.arange(len(c4)), c4['RUL_PERCENTAGE'], 'g-', label="blue")
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)

ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')
plt.ylim(0,1)

plt.xlim(0,350)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
#ax2 = ax1.twinx()
plt.plot(np.arange(len(c4)), c4['Label'], 'r-', label="green")
plt.ylim(0.4,1)

plt.plot(np.arange(len(c3[:101])), c3['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c5[:101])), c5['Label'][:101], 'b-', label="green")
plt.plot(np.arange(len(c6[:101])), c6['Label'][:101], 'b-', label="green")
plt.ylim(0.4,1)
plt.plot(np.arange(len(c4)), c4['RUL_PERCENTAGE'], 'g-', label="blue")
plt.ylim(0.4,1)
plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.axvline(50, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
#ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')



plt.xticks([0,20,40, 50,60,80,100])
plt.tick_params(axis='x', direction='in', length=3, pad=6, top=True)


plt.xlim(0,100)

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,8))
ax2 = ax1.twinx()
plt.plot(np.arange(len(c4)), c4['Label'], 'r-', label="green")


plt.plot(np.arange(len(c3)), c3['Label'], 'b-', label="green")
plt.plot(np.arange(len(c5)), c5['Label'], 'b-', label="green")
plt.plot(np.arange(len(c6)), c6['Label'], 'b-', label="green")


plt.plot(np.arange(len(c5)), c5['RUL_PERCENTAGE'], 'g-', label="blue")

plt.plot(np.arange(len(c4)), c4['RUL_PERCENTAGE'], 'g-', label="blue")

plt.axvline(100, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.axvline(50, 0, 1, color='lightgray', linestyle='--', linewidth=2)
ax1.set_xlabel('Tool Count')
ax1.set_ylabel('Predicted', color='r')
ax2.set_ylabel('RUL', color='g')



plt.xticks([0,20,40, 50,60,80,100])
plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=20, labelcolor='r', top=True)


plt.xlim(0,350)
plt.show()

# %%
print(c4['Label'][0],c3['Label'][0],c5['Label'][0],c6['Label'][0])
# Out:
# 0.7969376159880374 0.9739594760000684 0.9731471006303395 0.9738338089156653

# %%
print(c4['Label'][50],c3['Label'][50],c5['Label'][50],c6['Label'][50])
# Out:
# 0.763286823893968 0.85075812392088 0.8651016696260343 0.8607319835349382

# %%
print(c4['Label'][100],c3['Label'][100],c5['Label'][100],c6['Label'][100])
# Out:
# 0.607281960486286 0.6972626140329508 0.7215321405705108 0.6964824838080329
