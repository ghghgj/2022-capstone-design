# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data1= pd.read_json('/content/drive/Shareddrives/캡스톤디자인/동서기공 RUL data/max_points.json')

# %%
data1['max_points'][0]
# Out:
# [1383, 1562, 1254, 1228, 1116, 1078, 1065, 1094, 1221, 1934, 647]

# %%
# row 생략 없이 출력
pd.set_option('display.max_rows', None)
# col 생략 없이 출력
pd.set_option('display.max_columns', None)

# %%
data1.head()
# Out:
#    palletsNo      itemType                                            srcData  \
# 0          0  normal_cycle  [145, 146, 146, 147, 148, 149, 149, 151, 151, ...
# 1          0  normal_cycle  [153, 155, 154, 155, 155, 155, 156, 155, 157, ...
# 2          0  normal_cycle  [143, 145, 145, 147, 148, 149, 150, 151, 152, ...
# 3          0  normal_cycle  [146, 146, 147, 146, 148, 147, 149, 149, 150, ...
# 4          0  normal_cycle  [143, 143, 145, 146, 147, 149, 149, 151, 151, ...
#
#    sectionNumber  toolPreset  start  \
# 0              3          60   1028
# 1              3          60    943
# 2              3          60   1120
# 3              3          60   1153
# 4              3          60   1119
#
#                              sectionInspectionResult  \
# 0  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 1  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 2  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 3  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# ...

# %%
data1.describe()
# Out:
#        palletsNo  sectionNumber  toolPreset        start   path        itemId  \
# count      315.0          315.0       315.0   315.000000  315.0  3.150000e+02
# mean         0.0            3.0        60.0   991.780952    1.0  1.559060e+06
# std          0.0            0.0         0.0    71.396352    0.0  1.332533e+03
# min          0.0            3.0        60.0   913.000000    1.0  1.556996e+06
# 25%          0.0            3.0        60.0   929.000000    1.0  1.557808e+06
# 50%          0.0            3.0        60.0   973.000000    1.0  1.559006e+06
# 75%          0.0            3.0        60.0  1039.000000    1.0  1.560183e+06
# max          0.0            3.0        60.0  1160.000000    1.0  1.561480e+06
#
#                end   toolCount
# count   315.000000  315.000000
# mean   3048.069841   29.434921
# std      72.040162   17.541345
# min    2961.000000    1.000000
# 25%    2982.000000   14.000000
# 50%    3026.000000   29.000000
# 75%    3090.500000   45.000000
# ...

# %% [markdown]
# ### 나머지 데이터 불러오기

# %%
data2=pd.read_json('/content/drive/Shareddrives/캡스톤디자인/우일 오토텍 RUL data/data/data2 11_27-11_30.json')
#data2

# %%
data3= pd.read_json('/content/drive/Shareddrives/캡스톤디자인/우일 오토텍 RUL data/data/data3 11_23-11_26.json')
#data3

# %% [markdown]
# ### data 1 EDA

# %%
data1[data1['itemType']=='stop_cycle']
# Out:
#      palletsNo    itemType                                            srcData  \
# 297          0  stop_cycle  [162, 162, 163, 164, 165, 165, 166, 166, 167, ...
# 302          0  stop_cycle  [169, 170, 170, 169, 169, 169, 170, 172, 172, ...
#
#      sectionNumber  toolPreset  start  \
# 297              3          60    924
# 302              3          60    963
#
#                                sectionInspectionResult  \
# 297  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 302  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
#
#                       regDate                        sectionId  path   itemId  \
# 297  2021-07-27T02:30:39.424Z  //CNC_MEM/USER/PATH1/O675C0N3H3     1  1561164
# 302  2021-07-27T04:06:21.000Z  //CNC_MEM/USER/PATH1/O675C0N3H3     1  1561299
#
#       end channelName  toolCount
# 297  2981          S1         21
# 302  3126          S1         26

# %%
data1[["itemType","regDate","toolCount"]].iloc[297:304]
# Out:
#          itemType                   regDate  toolCount
# 297    stop_cycle  2021-07-27T02:30:39.424Z         21
# 298  normal_cycle  2021-07-27T02:41:36.000Z         22
# 299  normal_cycle  2021-07-27T02:46:57.000Z         23
# 300  normal_cycle  2021-07-27T02:52:24.000Z         24
# 301  normal_cycle  2021-07-27T02:58:00.000Z         25
# 302    stop_cycle  2021-07-27T04:06:21.000Z         26
# 303  normal_cycle  2021-07-27T04:17:31.000Z          1

# %%
data1[data1['toolPreset']==data1['toolCount']]
# Out:
#      palletsNo      itemType  \
# 42           0  normal_cycle
# 99           0  normal_cycle
# 158          0  normal_cycle
# 218          0  normal_cycle
# 277          0  normal_cycle
#
#                                                srcData  sectionNumber  \
# 42   [149, 151, 151, 153, 153, 154, 155, 155, 156, ...              3
# 99   [168, 170, 171, 173, 174, 175, 176, 178, 179, ...              3
# 158  [156, 157, 158, 159, 160, 162, 162, 165, 165, ...              3
# 218  [164, 166, 168, 170, 170, 172, 173, 174, 175, ...              3
# 277  [170, 172, 174, 175, 176, 178, 178, 179, 179, ...              3
#
#      toolPreset  start                            sectionInspectionResult  \
# 42           60   1030  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 99           60    916  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 158          60   1117  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# ...

# %%
import matplotlib.pyplot as plt


plt.plot(data1['toolCount'])
#toolcount가 2씩증가하는 상황이 가끔 발생

# %%
len(data1[data1['toolCount']==1]) #toolPreset 도달 5번, stop_cycle 1번
# Out:
# 6

# %% [markdown]
# ### data1의 부하 그래프

# %%
import matplotlib.pyplot as plt
#첫번째 사이클
for i in range(0,43):
    plt.ylim([1000, 4000]) 
    
    plt.plot(data1['srcData'][i])

# %%
#두번째 사이클
for i in range(44,100):
    plt.ylim([1000, 4000]) 

    plt.plot(data1['srcData'][i])

# %%
#세번째 사이클
for i in range(101,158):
    plt.ylim([1500, 3000]) 

    plt.plot(data1['srcData'][i])

# %% [markdown]
# normal cycle인 경우에는 값이 3천을 넘지않음

# %%
#네번째 사이클(중간에 stop)

for i in range(278,302):
    plt.ylim([1000, 16000]) 

    plt.plot(data1['srcData'][i])
    plt.show()

# %% [markdown]
# stop cycle이 발생하는 경우는 값이 크게 8천정도까지 크게 뛴다.

# %% [markdown]
# ###data 2 EDA

# %%
data2.describe()
# Out:
#        palletsNo  sectionNumber  toolPreset       start  path         itemId  \
# count       97.0           97.0        97.0   97.000000  97.0      97.000000
# mean         0.0            3.0        65.0  890.350515   1.0  759682.711340
# std          0.0            0.0         0.0   29.498249   0.0    1561.645399
# min          0.0            3.0        65.0  857.000000   1.0  757695.000000
# 25%          0.0            3.0        65.0  865.000000   1.0  758341.000000
# 50%          0.0            3.0        65.0  874.000000   1.0  759053.000000
# 75%          0.0            3.0        65.0  925.000000   1.0  761411.000000
# max          0.0            3.0        65.0  943.000000   1.0  762094.000000
#
#                end  toolCount
# count    97.000000  97.000000
# mean   2623.865979  27.886598
# std      26.823353  17.900114
# min    2585.000000   1.000000
# 25%    2605.000000  13.000000
# 50%    2607.000000  25.000000
# 75%    2653.000000  41.000000
# ...

# %%
data2["regDate"]
# Out:
# 0     2020-11-27T00:37:26.956Z
# 1     2020-11-27T00:42:26.189Z
# 2     2020-11-27T00:47:25.301Z
# 3     2020-11-27T00:53:39.776Z
# 4     2020-11-27T00:59:01.314Z
# 5     2020-11-27T01:25:15.883Z
# 6     2020-11-27T01:30:16.751Z
# 7     2020-11-27T01:35:55.752Z
# 8     2020-11-27T01:41:38.134Z
# 9     2020-11-27T01:47:14.102Z
# 10    2020-11-27T01:52:35.765Z
# 11    2020-11-27T01:57:54.125Z
# 12    2020-11-27T02:03:38.189Z
# 13    2020-11-27T02:09:18.973Z
# 14    2020-11-27T02:15:01.304Z
# 15    2020-11-27T02:19:59.010Z
# 16    2020-11-27T02:24:58.132Z
# 17    2020-11-27T02:29:57.343Z
# 18    2020-11-27T02:35:09.387Z
# 19    2020-11-27T02:40:30.939Z
# 20    2020-11-27T02:47:01.377Z
# 21    2020-11-27T02:53:10.923Z
# 22    2020-11-27T02:58:35.760Z
# 23    2020-11-27T04:11:41.182Z
# 24    2020-11-27T04:16:39.740Z
# 25    2020-11-27T04:21:38.971Z
# 26    2020-11-27T04:26:37.464Z
# 27    2020-11-27T04:31:47.620Z
# 28    2020-11-27T04:36:47.816Z
# 29    2020-11-27T04:41:48.589Z
# ...

# %%
data2[data2['itemType']=='stop_cycle']
# Out:
# Empty DataFrame
# Columns: [palletsNo, itemType, srcData, sectionNumber, toolPreset, start, sectionInspectionResult, regDate, sectionId, path, itemId, end, channelName, toolCount]
# Index: []

# %% [markdown]
# ### data2의 부하 그래프

# %%
#data2는 stopcycle이 없음 
plt.plot(data2['toolCount'])

# %%
for i in range(0,64):
    plt.ylim([1000, 16000]) 
    plt.plot(data2['srcData'][i])

# %%
for i in range(64,97):
    plt.ylim([1000, 16000]) 
    plt.plot(data2['srcData'][i])

# %% [markdown]
# ### data 3 EDA

# %%
data3.describe()
# Out:
#        palletsNo  sectionNumber  toolPreset       start   path         itemId  \
# count      218.0          218.0       218.0  218.000000  218.0     218.000000
# mean         0.0            3.0        65.0  872.009174    1.0  747331.876147
# std          0.0            0.0         0.0    6.232064    0.0    3945.294928
# min          0.0            3.0        65.0  860.000000    1.0  740940.000000
# 25%          0.0            3.0        65.0  868.000000    1.0  744903.250000
# 50%          0.0            3.0        65.0  872.000000    1.0  746679.500000
# 75%          0.0            3.0        65.0  876.000000    1.0  750213.000000
# max          0.0            3.0        65.0  887.000000    1.0  754076.000000
#
#                end   toolCount
# count   218.000000  218.000000
# mean   2607.958716   33.912844
# std       6.665348   19.464886
# min    2593.000000    1.000000
# 25%    2605.000000   17.000000
# 50%    2606.000000   35.500000
# 75%    2607.000000   51.000000
# ...

# %%
data3[data3['itemType']=='stop_cycle']
# Out:
#      palletsNo    itemType                                            srcData  \
# 209          0  stop_cycle  [59, 58, 59, 59, 58, 58, 58, 58, 58, 58, 59, 5...
#
#      sectionNumber  toolPreset  start  \
# 209              3          65    882
#
#                                sectionInspectionResult  \
# 209  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
#
#                       regDate                        sectionId  path  itemId  \
# 209  2020-11-26T01:28:37.684Z  //CNC_MEM/USER/PATH1/O675C0N3H3     1  753721
#
#       end channelName  toolCount
# 209  2629          S1         63

# %%
plt.plot(data3['toolCount'])

# %%
data3[data3['toolCount']==1]
# Out:
#      palletsNo      itemType  \
# 21           0  normal_cycle
# 84           0  normal_cycle
# 149          0  normal_cycle
# 210          0  normal_cycle
#
#                                                srcData  sectionNumber  \
# 21   [58, 59, 59, 58, 59, 58, 58, 59, 58, 59, 58, 5...              3
# 84   [59, 58, 59, 58, 59, 59, 58, 59, 58, 58, 58, 5...              3
# 149  [58, 59, 58, 58, 59, 58, 59, 58, 58, 59, 58, 5...              3
# 210  [58, 58, 58, 59, 59, 59, 59, 59, 59, 59, 58, 5...              3
#
#      toolPreset  start                            sectionInspectionResult  \
# 21           65    873  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 84           65    886  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 149          65    871  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 210          65    873  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
#
#                       regDate                        sectionId  path  itemId  \
# ...

# %%
for i in range(22,84):
    plt.ylim([1000, 10000]) 
    plt.plot(data3['srcData'][i])

# %%
for i in range(84,150):
    plt.ylim([1000, 10000]) 
    plt.plot(data3['srcData'][i])

# %%
for i in range(150,210):
    plt.ylim([1000, 10000]) 
    plt.plot(data3['srcData'][i])

# %%
data4=pd.read_json('/content/drive/Shareddrives/캡스톤디자인/우일 오토텍 RUL data/data/data4 6_25-6_26.json')

# %%
data4[data4['toolCount']==1]
# Out:
#      palletsNo      itemType  \
# 0            0  normal_cycle
# 59           0  normal_cycle
# 104          0  normal_cycle
# 164          0  normal_cycle
# 182          0  normal_cycle
#
#                                                srcData  sectionNumber  \
# 0    [29, 28, 28, 28, 27, 27, 27, 27, 26, 26, 26, 2...              3
# 59   [27, 27, 27, 26, 26, 26, 26, 25, 25, 25, 24, 2...              3
# 104  [29, 28, 28, 27, 27, 27, 26, 26, 25, 26, 25, 2...              3
# 164  [29, 29, 28, 28, 27, 27, 27, 27, 26, 26, 26, 2...              3
# 182  [30, 30, 29, 29, 28, 28, 27, 28, 27, 27, 26, 2...              3
#
#      toolPreset  start                            sectionInspectionResult  \
# 0            60    935  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 59           60   1106  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 104          60    931  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# ...

# %%
data4[data4['itemType']=='stop_cycle']
# Out:
#      palletsNo    itemType                                            srcData  \
# 103          0  stop_cycle  [27, 27, 26, 26, 26, 26, 26, 26, 25, 26, 25, 2...
# 181          0  stop_cycle  [30, 28, 28, 27, 27, 27, 27, 26, 26, 25, 25, 2...
#
#      sectionNumber  toolPreset  start  \
# 103              3          60   1042
# 181              3          60   1086
#
#                                sectionInspectionResult  \
# 103  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
# 181  [{'tool_no': 3, 'inspection_stop_type': 'NONE'...
#
#                       regDate                        sectionId  path   itemId  \
# 103  2021-06-25T12:11:40.384Z  //CNC_MEM/USER/PATH1/O675C0N3H3     1  1457005
# 181  2021-06-25T23:58:48.506Z  //CNC_MEM/USER/PATH1/O675C0N3H3     1  1459051
#
#       end channelName  toolCount
# 103  2857          S1         45
# 181  2885          S1         18

# %%
plt.plot(data4['toolCount'])

# %%
#첫번째 사이클
for i in range(0,59):
    plt.ylim([1000, 10000]) 
    plt.plot(data4['srcData'][i])

# %%
#두번째 사이클
for i in range(59,104):
    plt.ylim([1000, 10000]) 
    plt.plot(data4['srcData'][i])

# %%
#세번째 사이클
for i in range(104,164):
    plt.ylim([1000, 10000]) 
    plt.plot(data4['srcData'][i])

# %%
#네번째 사이클
for i in range(164,182):
    plt.ylim([1000, 10000]) 
    plt.plot(data4['srcData'][i])
